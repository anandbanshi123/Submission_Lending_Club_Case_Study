# %%
import numpy as np 
import pandas as pd 
# Data Visualization 
import seaborn as sns 
import matplotlib.pyplot as plt 
import plotly.express as px

# Extra - To Suppress warnings 
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("/Users/anandjha/Desktop/IBM/Submission_Lending_Club_Case_Study/data/loan.csv")
df.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
#
#   int_rate  installment grade sub_grade  ... num_tl_90g_dpd_24m  \
# 0   10.65%       162.87     B        B2  ...                NaN
# 1   15.27%        59.83     C        C4  ...                NaN
# 2   15.96%        84.33     C        C5  ...                NaN
# 3   13.49%       339.31     C        C1  ...                NaN
# 4   12.69%        67.79     B        B5  ...                NaN
#
#   num_tl_op_past_12m pct_tl_nvr_dlq  percent_bc_gt_75 pub_rec_bankruptcies  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Columns: 111 entries, id to total_il_high_credit_limit
# dtypes: float64(74), int64(13), object(24)
# memory usage: 33.6+ MB

# %%
df.info('All')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Data columns (total 111 columns):
#  #    Column                          Dtype
# ---   ------                          -----
#  0    id                              int64
#  1    member_id                       int64
#  2    loan_amnt                       int64
#  3    funded_amnt                     int64
#  4    funded_amnt_inv                 float64
#  5    term                            object
#  6    int_rate                        object
#  7    installment                     float64
#  8    grade                           object
#  9    sub_grade                       object
#  10   emp_title                       object
#  11   emp_length                      object
#  12   home_ownership                  object
#  13   annual_inc                      float64
#  14   verification_status             object
#  15   issue_d                         object
# ...

# %%
df.describe()
# Out:
#                  id     member_id     loan_amnt   funded_amnt  \
# count  3.971700e+04  3.971700e+04  39717.000000  39717.000000
# mean   6.831319e+05  8.504636e+05  11219.443815  10947.713196
# std    2.106941e+05  2.656783e+05   7456.670694   7187.238670
# min    5.473400e+04  7.069900e+04    500.000000    500.000000
# 25%    5.162210e+05  6.667800e+05   5500.000000   5400.000000
# 50%    6.656650e+05  8.508120e+05  10000.000000   9600.000000
# 75%    8.377550e+05  1.047339e+06  15000.000000  15000.000000
# max    1.077501e+06  1.314167e+06  35000.000000  35000.000000
#
#        funded_amnt_inv   installment    annual_inc           dti  \
# count     39717.000000  39717.000000  3.971700e+04  39717.000000
# mean      10397.448868    324.561922  6.896893e+04     13.315130
# std        7128.450439    208.874874  6.379377e+04      6.678594
# min           0.000000     15.690000  4.000000e+03      0.000000
# 25%        5000.000000    167.020000  4.040400e+04      8.170000
# ...

# %%
 #Casting variable into numeric in the dataset

numerical_columns=['id','member_id','loan_amnt','funded_amnt_inv','delinq_2yrs','inq_last_6mths',
                 'open_acc','pub_rec','revol_bal','total_acc','policy_code',
                 'acc_now_delinq', 'delinq_amnt']

df[numerical_columns] = df[numerical_columns].apply(pd.to_numeric)
df.head(10)
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
# 5  1075269    1311441       5000         5000           5000.0   36 months
# 6  1069639    1304742       7000         7000           7000.0   60 months
# 7  1072053    1288686       3000         3000           3000.0   36 months
# 8  1071795    1306957       5600         5600           5600.0   60 months
# 9  1071570    1306721       5375         5375           5350.0   60 months
#
#   int_rate  installment grade sub_grade  ... num_tl_90g_dpd_24m  \
# 0   10.65%       162.87     B        B2  ...                NaN
# ...

# %%
df.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade',
#        ...
#        'num_tl_90g_dpd_24m', 'num_tl_op_past_12m', 'pct_tl_nvr_dlq',
#        'percent_bc_gt_75', 'pub_rec_bankruptcies', 'tax_liens',
#        'tot_hi_cred_lim', 'total_bal_ex_mort', 'total_bc_limit',
#        'total_il_high_credit_limit'],
#       dtype='object', length=111)

# %%
num_data = df.select_dtypes(exclude=['object'])
num_data.describe()
# Out:
#                  id     member_id     loan_amnt   funded_amnt  \
# count  3.971700e+04  3.971700e+04  39717.000000  39717.000000
# mean   6.831319e+05  8.504636e+05  11219.443815  10947.713196
# std    2.106941e+05  2.656783e+05   7456.670694   7187.238670
# min    5.473400e+04  7.069900e+04    500.000000    500.000000
# 25%    5.162210e+05  6.667800e+05   5500.000000   5400.000000
# 50%    6.656650e+05  8.508120e+05  10000.000000   9600.000000
# 75%    8.377550e+05  1.047339e+06  15000.000000  15000.000000
# max    1.077501e+06  1.314167e+06  35000.000000  35000.000000
#
#        funded_amnt_inv   installment    annual_inc           dti  \
# count     39717.000000  39717.000000  3.971700e+04  39717.000000
# mean      10397.448868    324.561922  6.896893e+04     13.315130
# std        7128.450439    208.874874  6.379377e+04      6.678594
# min           0.000000     15.690000  4.000000e+03      0.000000
# 25%        5000.000000    167.020000  4.040400e+04      8.170000
# ...

# %%
num_data.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  installment  \
# 0  1077501    1296599       5000         5000           4975.0       162.87
# 1  1077430    1314167       2500         2500           2500.0        59.83
# 2  1077175    1313524       2400         2400           2400.0        84.33
# 3  1076863    1277178      10000        10000          10000.0       339.31
# 4  1075358    1311748       3000         3000           3000.0        67.79
#
#    annual_inc    dti  delinq_2yrs  inq_last_6mths  ...  num_tl_90g_dpd_24m  \
# 0     24000.0  27.65            0               1  ...                 NaN
# 1     30000.0   1.00            0               5  ...                 NaN
# 2     12252.0   8.72            0               2  ...                 NaN
# 3     49200.0  20.00            0               1  ...                 NaN
# 4     80000.0  17.94            0               0  ...                 NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Columns: 111 entries, id to total_il_high_credit_limit
# dtypes: float64(74), int64(13), object(24)
# memory usage: 33.6+ MB

# %%
import seaborn as sns
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1, 2, figsize=(12, 5))

sns.histplot(data=num_data, x='pub_rec_bankruptcies', ax=ax[0]);
sns.boxplot(data=num_data, y='loan_amnt', ax=ax[1]);

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 5))

sns.histplot(data=num_data, x='installment', ax=ax[0]);
sns.boxplot(data=num_data, y='installment', ax=ax[1]);

# %%
cat_features = df.select_dtypes(include=['object'])
cat_features.head()
# Out:
#          term int_rate grade sub_grade                 emp_title emp_length  \
# 0   36 months   10.65%     B        B2                       NaN  10+ years
# 1   60 months   15.27%     C        C4                     Ryder   < 1 year
# 2   36 months   15.96%     C        C5                       NaN  10+ years
# 3   36 months   13.49%     C        C1       AIR RESOURCES BOARD  10+ years
# 4   60 months   12.69%     B        B5  University Medical Group     1 year
#
#   home_ownership verification_status issue_d  loan_status  ...  \
# 0           RENT            Verified  Dec-11   Fully Paid  ...
# 1           RENT     Source Verified  Dec-11  Charged Off  ...
# 2           RENT        Not Verified  Dec-11   Fully Paid  ...
# 3           RENT     Source Verified  Dec-11   Fully Paid  ...
# 4           RENT     Source Verified  Dec-11      Current  ...
#
#                   title zip_code addr_state earliest_cr_line revol_util  \
# ...

# %%
cat_features.describe()
# Out:
#               term int_rate  grade sub_grade emp_title emp_length  \
# count        39717    39717  39717     39717     37258      38642
# unique           2      371      7        35     28820         11
# top      36 months   10.99%      B        B3   US Army  10+ years
# freq         29096      956  12020      2917       134       8879
#
#        home_ownership verification_status issue_d loan_status  ...  \
# count           39717               39717   39717       39717  ...
# unique              5                   3      55           3  ...
# top              RENT        Not Verified  Dec-11  Fully Paid  ...
# freq            18899               16921    2260       32950  ...
#
#                      title zip_code addr_state earliest_cr_line revol_util  \
# count                39706    39717      39717            39717      39667
# unique               19615      823         50              526       1089
# ...

# %%
def null_percentage(df):
    output = round(df.isnull().sum()/len(df.index)*100,2)
    return output
Na_col = null_percentage(df)
Na_col
# Out:
# id                              0.0
# member_id                       0.0
# loan_amnt                       0.0
# funded_amnt                     0.0
# funded_amnt_inv                 0.0
#                               ...
# tax_liens                       0.1
# tot_hi_cred_lim               100.0
# total_bal_ex_mort             100.0
# total_bc_limit                100.0
# total_il_high_credit_limit    100.0
# Length: 111, dtype: float64

# %%
Na_col = Na_col[Na_col>0]
Na_col
# Out:
# emp_title                       6.19
# emp_length                      2.71
# desc                           32.59
# title                           0.03
# mths_since_last_delinq         64.66
#                                ...
# tax_liens                       0.10
# tot_hi_cred_lim               100.00
# total_bal_ex_mort             100.00
# total_bc_limit                100.00
# total_il_high_credit_limit    100.00
# Length: 68, dtype: float64

# %%
Na_col.count
# Out:
# <bound method Series.count of emp_title                       6.19
# emp_length                      2.71
# desc                           32.59
# title                           0.03
# mths_since_last_delinq         64.66
#                                ...
# tax_liens                       0.10
# tot_hi_cred_lim               100.00
# total_bal_ex_mort             100.00
# total_bc_limit                100.00
# total_il_high_credit_limit    100.00
# Length: 68, dtype: float64>

# %%
plt.figure(figsize = (10,4), dpi=100)
Na_col.plot(kind = "bar")
plt.title("Null values in columns")
plt.xlabel('Percentage of Null')
plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 5))

sns.histplot(data=num_data, x='loan_status', ax=ax[0]);
sns.boxplot(data=num_data, y='installment', ax=ax[1]);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 3
#       1 fig, ax = plt.subplots(1, 2, figsize=(12, 5))
# ----> 3 sns.histplot(data=num_data, x='loan_status', ax=ax[0]);
#       4 sns.boxplot(data=num_data, y='installment', ax=ax[1]);
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/distributions.py:1379, in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1358 def histplot(
#    1359     data=None, *,
#    1360     # Vector variables
#    (...)
#    1376     **kwargs,
#    1377 ):
# -> 1379     p = _DistributionPlotter(
#    1380         data=data,
# ...
